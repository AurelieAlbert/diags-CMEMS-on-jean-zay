# %%
import papermill as pm

# %%
ymin=2010;mmin=1;dmin=1
ymax=2010;mmax=9;dmax=30
# depth of the desired comparison profile in m
depthmin=100
# radius of the circle around the profile location in which we take the modeled profiles, in °  
radius_max=0.25
# period of time around the profile sampling date in which we take the modeled profiles, in days
period=5
# minimum amount of model profiles to be considered to make a significant statistical comparison, for instance in a 1° square and 30-days window we have 2.6 millions modeled profiles, in a 0.5°x10 days 216 000
number_of_model_profiles=100000
pm.execute_notebook('2020-08-03-AA-selection-script-with-options.ipynb','2020-08-03-AA-selection-script-with-options-output1.ipynb',parameters=dict(ymin=ymin,mmin=mmin,dmin=dmin,ymax=ymax,mmax=mmax,dmax=dmax,depthmin=depthmin,radius_max=radius_max,period=period,number_of_model_profiles=number_of_model_profiles))
pm.execute_notebook('2020-08-05-AA-map-selected-profiles.ipynb','2020-08-05-AA-map-selected-profiles-output1.ipynb',parameters=dict(ymin=ymin,mmin=mmin,dmin=dmin,ymax=ymax,mmax=mmax,dmax=dmax,depthmin=depthmin,radius_max=radius_max,period=period,number_of_model_profiles=number_of_model_profiles))
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-05T11:45:48.503018',
#      'end_time': '2020-08-05T11:45:48.507260',
#      'duration': 0.004242,
#      'status': 'completed'}},
#    'source': '## Plot the locations of all profiles'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-08-05T11:45:48.511989',
#      'end_time': '2020-08-05T11:45:48.520905',
#      'duration': 0.008916,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2020-08-05T11:45:48.518836Z',
#      'iopub.execute_input': '2020-08-05T11:45:48.519317Z',
#      'iopub.status.idle': '2020-08-05T11:45:48.520493Z',
#      'shell.execute_reply': '2020-08-05T11:45:48.520800Z'}},
#    'outputs': [],
# ...
