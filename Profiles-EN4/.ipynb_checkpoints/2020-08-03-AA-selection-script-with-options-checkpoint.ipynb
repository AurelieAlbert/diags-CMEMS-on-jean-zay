# %% [markdown]
# ## Selection of EN4 profiles to compare to a simulation

# %% [markdown]
# In this script the EN4 database is browsed in order to find the profiles that will be compare to the outputs of one simulation.
#
# The comparison will not be a simple colocation of the profile inside the model grid but we want to make a statistical comparison of the observed profile with  a significant number of profiles close to it in the model (close in terms of space and time, for instance in a 0,5° radius around the profile location and 10 days before and after it has been sampled)
#
# Therefor the selected profiles must have to be relevant according to some criteria :
#   - they must be inside the domain of simulation (the mask file of the configuration file must be provided)
#   - they must be sampled inside the period of simulation (the period shortened by a certain amount of days must be provided)
#   - they must go as deep as a given depth (according to the desired depth for the comparison profiles)
#   - they must be in a location where there are enough model profiles (for instance if profile is too close to an island or the coast)

# %% [markdown]
# ### Criteria of profiles selection

# %%
# location and name of the maskfile of the model configuration
coordfile='/gpfsstore/rech/egi/commun/MEDWEST60/MEDWEST60-I/MEDWEST60_mesh_hgr.nc4'
maskfile='/gpfsstore/rech/egi/commun/MEDWEST60/MEDWEST60-I/MEDWEST60_mask.nc4'
zgrdfile='/gpfsstore/rech/egi/commun/MEDWEST60/MEDWEST60-I/MEDWEST60_mesh_zgr.nc4'
# period of the simulation (year,month,day)
ymin=2010;mmin=1;dmin=1
ymax=2010;mmax=9;dmax=30
# depth of the desired comparison profile in m
depthmin=1000
# radius of the circle around the profile location in which we take the modeled profiles, in °  
radius_max=0.25
# period of time around the profile sampling date in which we take the modeled profiles, in days
period=5
# minimum amount of model profiles to be considered to make a significant statistical comparison, for instance in a 1° square and 30-days window we have 2.6 millions modeled profiles, in a 0.5°x10 days 216 000
number_of_model_profiles=100000
# name of the json file in which selection of profiles informations will be stored
jsonfile='MEDWEST60_y'+str(ymin)+'m'+str(mmin)+'d'+str(dmin)+'-y'+str(ymax)+'m'+str(mmax)+'d'+str(dmax)+'_'+str(depthmin)'+m_'+str(radius_max)+'x'+str(period)+'d_'+str(number_of_model_profiles)+'.json'

# %% [markdown]
# ### imports of librairies

# %%
import numpy as np
import dask
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import glob as glob
import time
from datetime import date
import io
import json
import seawater
import sys

# %% [markdown]
# ### determining the dates

# %%
datemin=datetime.date(ymin,mmin,dmin)
datemax=datetime.date(ymax,mmax,dmax)
# list of days between datemin and datemax
def date_range(start, end, period):
    r = (end+datetime.timedelta(days=1)-start).days
    return [start+datetime.timedelta(days=i) for i in range(period,r-period)]
dateList = date_range(datemin, datemax,period) 
for date in dateList:
    print(date)
# Out:
# 2010-01-06
# 2010-01-07
# 2010-01-08
# 2010-01-09
# 2010-01-10
# 2010-01-11
# 2010-01-12
# 2010-01-13
# 2010-01-14
# 2010-01-15
# 2010-01-16
# 2010-01-17
# 2010-01-18
# 2010-01-19
# 2010-01-20
# 2010-01-21
# 2010-01-22
# 2010-01-23
# 2010-01-24
# 2010-01-25
# 2010-01-26
# 2010-01-27
# 2010-01-28
# 2010-01-29
# 2010-01-30
# 2010-01-31
# 2010-02-01
# 2010-02-02
# 2010-02-03
# 2010-07-22
# 2010-07-23
# 2010-07-24
# 2010-07-25
# 2010-07-26
# 2010-07-27
# 2010-07-28
# 2010-07-29
# 2010-07-30
# 2010-07-31
# 2010-08-01
# 2010-08-02
# 2010-08-03
# 2010-08-04
# 2010-08-05
# 2010-08-06
# 2010-08-07
# 2010-08-08
# 2010-08-09
# 2010-08-10
# 2010-08-11
# 2010-08-12
# 2010-08-13
# 2010-08-14
# 2010-08-15
# 2010-08-16
# 2010-08-17
# 2010-08-18
# 2010-08-19
# 2010-08-20
# 2010-08-21
# 2010-08-22
# 2010-08-23
# 2010-08-24
# 2010-08-25
# 2010-08-26
# 2010-08-27
# 2010-08-28
# 2010-08-29
# 2010-08-30
# 2010-08-31
# 2010-09-01
# 2010-09-02
# 2010-09-03
# 2010-09-04
# 2010-09-05
# 2010-09-06
# 2010-09-07
# 2010-09-08
# 2010-09-09
# 2010-09-10
# 2010-09-11
# 2010-09-12
# 2010-09-13
# 2010-09-14
# 2010-09-15
# 2010-09-16
# 2010-09-17
# 2010-09-18
# 2010-09-19
# 2010-09-20
# 2010-09-21
# 2010-09-22
# 2010-09-23
# 2010-09-24
# 2010-09-25

# %% [markdown]
# ### List of all EN4 files to search in

# %%
diren4="/gpfswork/rech/egi/rote001/EN4/"
list_filesEN4=[]
for date in dateList:
    year=date.year
    month=date.month
    day=date.day
    mm="{:02d}".format(month) #month on 2 digits
    dd="{:02d}".format(day) # day on 2 digits
    list_filesEN4.append(str(year)+str(mm)+str(dd)+'_prof.nc')
print(list_filesEN4)
# Out:
# ['20100106_prof.nc', '20100107_prof.nc', '20100108_prof.nc', '20100109_prof.nc', '20100110_prof.nc', '20100111_prof.nc', '20100112_prof.nc', '20100113_prof.nc', '20100114_prof.nc', '20100115_prof.nc', '20100116_prof.nc', '20100117_prof.nc', '20100118_prof.nc', '20100119_prof.nc', '20100120_prof.nc', '20100121_prof.nc', '20100122_prof.nc', '20100123_prof.nc', '20100124_prof.nc', '20100125_prof.nc', '20100126_prof.nc', '20100127_prof.nc', '20100128_prof.nc', '20100129_prof.nc', '20100130_prof.nc', '20100131_prof.nc', '20100201_prof.nc', '20100202_prof.nc', '20100203_prof.nc', '20100204_prof.nc', '20100205_prof.nc', '20100206_prof.nc', '20100207_prof.nc', '20100208_prof.nc', '20100209_prof.nc', '20100210_prof.nc', '20100211_prof.nc', '20100212_prof.nc', '20100213_prof.nc', '20100214_prof.nc', '20100215_prof.nc', '20100216_prof.nc', '20100217_prof.nc', '20100218_prof.nc', '20100219_prof.nc', '20100220_prof.nc', '20100221_prof.nc', '20100222_prof.nc', '20100223_prof.nc', '20100224_prof.nc', '20100225_prof.nc', '20100226_prof.nc', '20100227_prof.nc', '20100228_prof.nc', '20100301_prof.nc', '20100302_prof.nc', '20100303_prof.nc', '20100304_prof.nc', '20100305_prof.nc', '20100306_prof.nc', '20100307_prof.nc', '20100308_prof.nc', '20100309_prof.nc', '20100310_prof.nc', '20100311_prof.nc', '20
# %% [markdown]
# #### Localisation of the profile location inside model domain

# %%
def loc(fileEN4,prof):
    # open the maskfile and get lat lon and mask
    ds=xr.open_dataset(maskfile)
    lat=ds.nav_lat
    lon=ds.nav_lon
    latmin,latmax,lonmin,lonmax=(lat.min(),lat.max(),lon.min(),lon.max())
    tmask=ds.tmask    
    #open the profile file and read the infos on latitude, longitude and date 
    tfileEN4=diren4+fileEN4
    dsen4=xr.open_dataset(tfileEN4)
    laten4=dsen4['LATITUDE'][prof].values
    lonen4=dsen4['LONGITUDE'][prof].values
    
    if (lonmin.values<lonen4)&(lonen4<lonmax.values)&(latmin.values<laten4)&(laten4<latmax.values):
            with open('txt/prof0.txt','w') as txt_file:
                txt_file.write('Profile_'+str(fileEN4)+'_'+str(prof)+' '+str(lonen4)+' '+str(laten4))
            # !rm ij_found.out
            # !/gpfswork/rech/egi/rote001/git/sosie/bin/ij_from_lon_lat.x -i $coordfile -p txt/prof0.txt >/dev/null

            with open('ij_found.out','r') as txt_file:
                last_line = txt_file.readlines()[-1]
                if last_line[1] == '#':
                    print('Profile no '+str(prof)+' in file '+str(fileEN4)+' is not in the domain, do not keep')
                    i0,j0=-1,-1
                else:
                    print('Profile no '+str(prof)+' in file '+str(fileEN4)+' is in the domain, go proceed')
                    i0=int(last_line.split()[1])
                    j0=int(last_line.split()[2])
    else:
        print('Profile no '+str(prof)+' in file '+str(fileEN4)+' is not in the domain, do not keep')
#        print('Profile coordinates are '+str(lonen4)+'°E x '+str(laten4)+'°N')
#        print('Model domain is '+str(latmin.values)+'-'+str(latmax.values)+'°E x '+str(lonmin.values)+'-'+str(lonmax.values)+'°N')
        i0,j0=-1,-1
       
    return i0,j0

# %% [markdown]
# #### Check if profile location is on land

# %%
def check_prof_in_ocean(i0,j0):
    print('check if profile is in the ocean : ')
    dsN=xr.open_dataset(maskfile)
    tmaskN=dsN.tmask
    if tmaskN[0,0,int(j0)-1,int(i0)-1] == 1:
        check=0
    else:
        check=1
    return check

# %% [markdown]
# #### check depth of profile

# %%
def check_prof_depth(fileEN4,prof):
    print('check if profile has a good depth : ')
    #open the profile file and read the infos on pressure and latitude
    tfileEN4=diren4+fileEN4
    dsen4=xr.open_dataset(tfileEN4)
    presen4=dsen4['PRES_ADJUSTED'][prof].values
    laten4=dsen4['LATITUDE'][prof].values
    #convert pressure to depth
    depthen4=seawater.dpth(presen4,laten4)
    #look for the last level
    indzprof=np.min(np.where(np.isnan(depthen4)==True))
    dmax=depthen4[indzprof-1]
    print('profile max depth is '+str(dmax)+' m')
    if dmax >= depthmin:
        check=0
    else:
        check=1
    return check

# %% [markdown]
# #### check if there are enough model profiles around the obs profile

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib.patches as mpatches

def map_profile_from_jsonfile(lon,lat,radius,lonmin, lonmax, latmin, latmax):
    fig=plt.figure(figsize=(20,15))
    ax = plt.subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
    ax.set_extent((lonmin, lonmax, latmin, latmax))
    ax.coastlines(resolution="10m")
    gl = ax.gridlines(draw_labels=True, linestyle=':', color='black',
                      alpha=0.5)
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    ax.tick_params('both',labelsize=22)
    ax.add_patch(mpatches.Circle(xy=[lon,lat], radius=radius, color='green', alpha=0.3, transform=ccrs.PlateCarree(), zorder=30))
    plt.scatter(lon,lat, c='g', linewidth='0', s=18);

def check_number_profile(fileEN4,prof,i0,j0,dmap=0):
    print('check if there are enough model profiles : ')
    #open mask file and read lat, lon and mask
    ds=xr.open_dataset(maskfile)
    lat=ds.nav_lat
    lon=ds.nav_lon
    tmask=ds.tmask
    lat_mask=np.ma.masked_where(tmask[0,0]==0.,lat)
    lon_mask=np.ma.masked_where(tmask[0,0]==0.,lon)
    latmin,latmax,lonmin,lonmax=(lat_mask.min(),lat_mask.max(),lon_mask.min(),lon_mask.max())
    #open the vertical grid file and read the vertical axis of model
    dsH=xr.open_dataset(zgrdfile)
    depthN=dsH.gdept_1d[0]
    #open the profile file and read the infos on latitude, longitude
    tfileEN4=diren4+fileEN4
    dsen4=xr.open_dataset(tfileEN4)
    laten4=dsen4['LATITUDE'][prof].values
    lonen4=dsen4['LONGITUDE'][prof].values
    #region englobing the model profiles
    gdpts=np.int(np.round(radius_max*60))
    mask_prof=tmask[0,:,j0-gdpts:j0+gdpts,i0-gdpts:i0+gdpts]
    nb_profiles=np.sum(mask_prof[0]).values*24*period*2
    print('There are a total of '+str(nb_profiles)+' model oceanic profiles in a '+str(radius_max)+'° radius around the obs profile and '+str(period)+' days before and after the sampling')
    #retrieve the depth of the last level for every point in the region
    d,ly,lx=mask_prof.shape
    nb_prof_gd=0
    for j in np.arange(ly):
        for i in np.arange(lx):
            dd=depthN[np.min(np.where(mask_prof[:,j,i].values<1))]
            if dd >= depthmin:
                nb_prof_gd+=1
    print('There are a total of '+str(nb_prof_gd*24*period*2)+' model oceanic profiles with enough depth')
    if dmap == 1:
        map_profile_from_jsonfile(lonen4,laten4,radius_max,lonmin, lonmax, latmin, latmax)
    if nb_prof_gd*24*period*2 > number_of_model_profiles:
        check=0
    else:
        check=1
    return check

# %% [markdown]
# #### function to select one profile and save its characteristics in the json file

# %%
def make_dict(fileEN4,prof,i0,j0,dictyml):
    print('Adding profile to the dict')
    #open the profile file and read the infos on latitude, longitude
    tfileEN4=diren4+fileEN4
    dsen4=xr.open_dataset(tfileEN4)
    laten4=dsen4['LATITUDE'][prof].values
    lonen4=dsen4['LONGITUDE'][prof].values
    dayen4=dsen4['JULD'][prof].values
    if dictyml:
        up={'Profile_'+str(fileEN4)+'_'+str(prof):{'reference':'Profile_'+str(fileEN4)+'_'+str(prof),
                                                        'file':fileEN4,'profile no':int(prof),
                                                        'latitude':float(laten4),
                                                        'longitude':float(lonen4),
                                                        'date':str(dayen4),
                                                        'i0':int(i0),'j0':int(j0)}}
        dictyml.update(up)
    else:
        dictyml={'Profile_'+str(fileEN4)+'_'+str(prof):{'reference':'Profile_'+str(fileEN4)+'_'+str(prof),
                                                        'file':fileEN4,'profile no':int(prof),
                                                        'latitude':float(laten4),
                                                        'longitude':float(lonen4),
                                                        'date':str(dayen4),
                                                        'i0':int(i0),'j0':int(j0)}}
    return dictyml

# %%
# %%time
#loop on all the files

jdict={}
for f in range(len(list_filesEN4)):
    fileEN4=list_filesEN4[f]
    ds=xr.open_dataset(diren4+fileEN4)
    nprof=len(ds.N_PROF)
    for prof in range(nprof):
        i0,j0=loc(fileEN4,prof)
        if (i0,j0) == (-1,-1):
            print('profile is not in the domain at all')
            continue
        check=check_prof_in_ocean(i0,j0)
        if check == 1:
            print('no, profile is on the land')
            continue
        print('yes, profile is in the ocean')
        check=check_prof_depth(fileEN4,prof)
        if check == 1:
            print('no, profile is not deep enough')
            continue
        print('yes, profile is deep enough')
        check_number_profile(fileEN4,prof,i0,j0)
        print(check)
        if check == 1:
            print('no, there are not enough model profiles')
            continue
        print('yes, there are enough model profiles')
        jdict=make_dict(fileEN4,prof,i0,j0,jdict)
    
#write dict in a json file           
with io.open('txt/'+str(jsonfile), 'a+', encoding='utf8') as outfile:
    outfile.write(str(json.dumps(jdict, sort_keys=True,indent=4, separators=(',', ': '))))
# Out:
# Profile no 0 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 1 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 2 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 3 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 4 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 5 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 6 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 7 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 8 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 9 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 10 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 11 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 12 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 13 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 14 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 15 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 16 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 17 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 18 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 19 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 20 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 21 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 22 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 23 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 24 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 25 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 26 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 27 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 28 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 29 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 30 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 31 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 32 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 33 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 34 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 35 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 36 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 37 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 38 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 39 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 40 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 41 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 42 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 43 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 44 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 45 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 46 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 47 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 48 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 49 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 50 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 51 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 52 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 53 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 54 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 55 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 56 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 57 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 58 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 59 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 60 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 61 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 62 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 63 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 64 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 65 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 66 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 67 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 68 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 69 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 70 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 71 in file 20100106_prof.nc is in the domain, go proceed
# check if profile is in the ocean :
# yes, profile is in the ocean
# check if profile has a good depth :
# profile max depth is 1959.4314 m
# yes, profile is deep enough
# check if there are enough model profiles :
# There are a total of 216000 model oceanic profiles in a 0.25° radius around the obs profile and 5 days before and after the sampling
# There are a total of 216000 model oceanic profiles with enough depth
# 0
# yes, there are enough model profiles
# Adding profile to the dict
# Profile no 72 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 73 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 74 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 75 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 76 in file 20100106_prof.nc is in the domain, go proceed
# check if profile is in the ocean :
# yes, profile is in the ocean
# check if profile has a good depth :
# profile max depth is 1534.3623 m
# yes, profile is deep enough
# check if there are enough model profiles :
# There are a total of 216000 model oceanic profiles in a 0.25° radius around the obs profile and 5 days before and after the sampling
# There are a total of 216000 model oceanic profiles with enough depth
# 0
# yes, there are enough model profiles
# Adding profile to the dict
# Profile no 77 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 78 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 79 in file 20100106_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 0 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 1 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 2 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 3 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 4 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 5 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 6 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 7 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 8 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 9 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 10 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 11 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 12 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 13 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 14 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 15 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 16 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 17 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 18 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 19 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 20 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 21 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 22 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 23 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 24 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 25 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 26 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 27 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 28 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 29 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 30 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 31 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 32 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 33 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 34 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 35 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 36 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 37 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 38 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 39 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 40 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 41 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 42 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 43 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 44 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 45 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 46 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 47 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 48 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 49 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 50 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 51 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 52 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 53 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 54 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 55 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 56 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 57 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 58 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 59 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 60 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 61 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 62 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 63 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 64 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 65 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 66 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 67 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 68 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 69 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 70 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 71 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 72 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 73 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 74 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 75 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 76 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 77 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 78 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 79 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 80 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 81 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 82 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 83 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 84 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 85 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 86 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 87 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 88 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 89 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 90 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 91 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 92 in file 20100107_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 0 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 1 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 2 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 3 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 4 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 5 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 6 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 7 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 8 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 9 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 10 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 11 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 12 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 13 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 14 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 15 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 16 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 17 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 18 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 19 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 20 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 21 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 22 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 23 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 24 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 25 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 26 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 27 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 28 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 29 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 30 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 31 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 32 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 33 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 34 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 35 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 36 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 37 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 38 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 39 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 40 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 41 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 42 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 43 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 44 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 45 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 46 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 47 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 48 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 49 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 50 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 51 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 52 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 53 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 54 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 55 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 56 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 57 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 58 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 59 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 60 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 61 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 62 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 63 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 64 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 65 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 66 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 67 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 68 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 69 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 70 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 71 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 72 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 73 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 74 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 75 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 76 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 77 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 78 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 79 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 80 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 81 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 82 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 83 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 84 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 85 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 86 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 87 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 88 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 89 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 90 in file 20100108_prof.nc is in the domain, go proceed
# check if profile is in the ocean :
# yes, profile is in the ocean
# check if profile has a good depth :
# profile max depth is 1466.1553 m
# yes, profile is deep enough
# check if there are enough model profiles :
# There are a total of 216000 model oceanic profiles in a 0.25° radius around the obs profile and 5 days before and after the sampling
# There are a total of 216000 model oceanic profiles with enough depth
# 0
# yes, there are enough model profiles
# Adding profile to the dict
# Profile no 91 in file 20100108_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 92 in file 20100108_prof.nc is in the domain, go proceed
# check if profile is in the ocean :
# yes, profile is in the ocean
# check if profile has a good depth :
# profile max depth is 1462.3887 m
# yes, profile is deep enough
# check if there are enough model profiles :
# There are a total of 216000 model oceanic profiles in a 0.25° radius around the obs profile and 5 days before and after the sampling
# There are a total of 216000 model oceanic profiles with enough depth
# 0
# yes, there are enough model profiles
# Adding profile to the dict
# Profile no 0 in file 20100109_prof.nc is in the domain, go proceed
# check if profile is in the ocean :
# yes, profile is in the ocean
# check if profile has a good depth :
# profile max depth is 1462.7957 m
# yes, profile is deep enough
# check if there are enough model profiles :
# There are a total of 216000 model oceanic profiles in a 0.25° radius around the obs profile and 5 days before and after the sampling
# There are a total of 216000 model oceanic profiles with enough depth
# 0
# yes, there are enough model profiles
# Adding profile to the dict
# Profile no 1 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 2 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 3 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 4 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 5 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 6 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 7 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 8 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 9 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 10 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 11 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 12 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 13 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 14 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 15 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 16 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 17 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 18 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 19 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 20 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 21 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 22 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 23 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 24 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 25 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 26 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 27 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 28 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 29 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 30 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 31 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 32 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 33 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 34 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 35 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 36 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 37 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 38 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 39 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 40 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 41 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 42 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 43 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 44 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 45 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 46 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 47 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 48 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 49 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 50 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 51 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 52 in file 20100109_prof.nc is in the domain, go proceed
# check if profile is in the ocean :
# yes, profile is in the ocean
# check if profile has a good depth :
# profile max depth is 390.32114 m
# no, profile is not deep enough
# Profile no 53 in file 20100109_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no
in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 9 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 10 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 11 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 12 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 13 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 14 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 15 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 16 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 17 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 18 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 19 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 20 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 21 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 22 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 23 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 24 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 25 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 26 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 27 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 28 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 29 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 30 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 31 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 32 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 33 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 34 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 35 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 36 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 37 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 38 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 39 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 40 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 41 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 42 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 43 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 44 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 45 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 46 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 47 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 48 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 49 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 50 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 51 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 52 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 53 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 54 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 55 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 56 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 57 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 58 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 59 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 60 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 61 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 62 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 63 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 64 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 65 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 66 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 67 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 68 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 69 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 70 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 71 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 72 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 73 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 74 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 75 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 76 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 77 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 78 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 79 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 80 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 81 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 82 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 83 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 84 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 85 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 86 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 87 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 88 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 89 in file 20100925_prof.nc is in the domain, go proceed
# check if profile is in the ocean :
# yes, profile is in the ocean
# check if profile has a good depth :
# profile max depth is 1509.5702 m
# yes, profile is deep enough
# check if there are enough model profiles :
# There are a total of 216000 model oceanic profiles in a 0.25° radius around the obs profile and 5 days before and after the sampling
# There are a total of 216000 model oceanic profiles with enough depth
# 0
# yes, there are enough model profiles
# Adding profile to the dict
# Profile no 90 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 91 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 92 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 93 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 94 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 95 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 96 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 97 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# Profile no 98 in file 20100925_prof.nc is not in the domain, do not keep
# profile is not in the domain at all
# CPU times: user 9min 46s, sys: 3min 4s, total: 12min 50s
# Wall time: 17min 17s

# %% [markdown]
# ## Plot the locations of all profiles

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# %%
sourcefile=open(jsonfile,'rU',encoding='utf-8')
infos=json.load(sourcefile)
nb_profilesEN4=len(infos)
list_profiles=infos.keys()

all_lat=np.zeros((nb_profilesEN4))
all_lon=np.zeros((nb_profilesEN4))
    
for prof in np.arange(nb_profilesEN4):
    reference =  str(list(list_profiles)[prof])
    lat_prof = infos[reference]['latitude']
    lon_prof = infos[reference]['longitude']
    all_lat[prof]=lat_prof
     all_lon[prof]=lon_prof

# %%
len(all_lon)

# %%
def map_profiles_from_jsonfile(all_lat,all_lon):
    fig=plt.figure(figsize=(20,15))
    ax = plt.subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
    ax.set_extent((lonmin, lonmax, latmin, latmax))
    ax.coastlines(resolution="10m")
    gl = ax.gridlines(draw_labels=True, linestyle=':', color='black',
                      alpha=0.5)
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    ax.tick_params('both',labelsize=22)

    plt.scatter(all_lon, all_lat, c='g', linewidth='0', s=18);
    plt.title('There are '+str(len(all_lon))+' '+str(depthmin)+'m-deep EN4 profiles in MEDWEST60 for '+str(datemin)+' to '+str(datemax)+' period with model outputs in a '+str(radius_max)+'° raidus and '+str(period)+' days period around', size=20);
    plt.savefig('plots/MEDWEST60_y'+str(ymin)+'m'+str(mmin)+'d'+str(dmin)+'-y'+str(ymax)+'m'+str(mmax)+'d'+str(dmax)+'_'+str(depthmin)'+m_'+str(radius_max)+'x'+str(period)+'d_'+str(number_of_model_profiles)+'.png')

# %%
map_profiles_from_jsonfile(all_lat,all_lon)
